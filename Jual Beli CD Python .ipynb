# %%
cd = []


def show_cd():
    if len(cd)<=0:
        print("masukan data baru")
    else:
        for indeks in range(len(cd)):
            print("", (indeks, cd[indeks]))
    pilih_menu()    

def insert_cd():
    cd_baru = input("nama cd baru: ")
    cd.append(cd_baru)

    pilih_menu()

def edit_cd():
    if(indeks > len(cd)):
        print("id salah")
    else:
        for i in range(len(cd)):
            nama_baru = input("edit judul cd: ", cd(i))
            cd = nama_baru
    
    show_cd()
  
    
def delete_cd():
    show_cd()
    indeks = input("masukan id cd: ")
    if(indeks > len(cd)):
        print("id salah")
    else:
        cd.remove(cd[indeks])
   
    menu = input("PILIH MENU> ")
    pilih_menu()
    
def show_menu():
    print("FLOODRIVER CD STORE")
    print("--------------------")
    print("[1] Lihat CD")
    print("[2] Masukan CD")
    print("[3] Edit CD")
    print("[4] Hapus CD")
    
def pilih_menu():
    menu = input("PILIH MENU> ")
    if(menu=="1"):
        print("[1] Lihat CD")
        show_cd()
    elif (menu=="2"):
        print("[2] Masukan CD")
        insert_cd()
    elif(menu=="3"):
        print("[3] Edit CD")
        edit_cd()
    elif(menu=="4"):
        print("[4] Hapus CD")
        delete_cd()
        exit()
    else:
        print("Salah pilih bos")
        
        pilih_menu()

if(True):
    show_menu()
    pilih_menu()
# Out:
# FLOODRIVER CD STORE
# --------------------
# [1] Lihat CD
# [2] Masukan CD
# [3] Edit CD
# [4] Hapus CD
# PILIH MENU> 2
# [2] Masukan CD
# nama cd baru: slkjlssd
# PILIH MENU> 2
# [2] Masukan CD
# nama cd baru: ndksjdsds
# PILIH MENU> 3
# [3] Edit CD
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-137-a0f02fdc3c34> in <module>
#      68 if(True):
#      69     show_menu()
# ---> 70     pilih_menu()
#      71
#      72
#
# <ipython-input-137-a0f02fdc3c34> in pilih_menu()
#      53     elif (menu=="2"):
#      54         print("[2] Masukan CD")
# ---> 55         insert_cd()
#      56     elif(menu=="3"):
#      57         print("[3] Edit CD")
#
# <ipython-input-137-a0f02fdc3c34> in insert_cd()
#      14     cd.append(cd_baru)
#      15
# ---> 16     pilih_menu()
#      17
#      18 def edit_cd():
#
# <ipython-input-137-a0f02fdc3c34> in pilih_menu()
#      53     elif (menu=="2"):
#      54         print("[2] Masukan CD")
# ---> 55         insert_cd()
#      56     elif(menu=="3"):
#      57         print("[3] Edit CD")
#
# <ipython-input-137-a0f02fdc3c34> in insert_cd()
#      14     cd.append(cd_baru)
#      15
# ---> 16     pilih_menu()
#      17
#      18 def edit_cd():
#
# <ipython-input-137-a0f02fdc3c34> in pilih_menu()
#      56     elif(menu=="3"):
#      57         print("[3] Edit CD")
# ---> 58         edit_cd()
#      59     elif(menu=="4"):
#      60         print("[4] Hapus CD")
#
# <ipython-input-137-a0f02fdc3c34> in edit_cd()
#      17
#      18 def edit_cd():
# ---> 19     if(indeks > len(cd)):
#      20         print("id salah")
#      21     else:
#
# UnboundLocalError: local variable 'cd' referenced before assignment
